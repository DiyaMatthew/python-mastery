# %%
import pandas as pd

# %%
people = { "first_name" : ["Smith","Rowan","Alfie","John"],
           "last_name" : ["Will","Doe","Doe","Doe"],
           "age" : ["34", "45","23","45"],
           "email" : ["smithwill@gmail.com", "rowanjohn@gmail.com", "alfiehaze@gmail.com", "johndoe@gmail.com"]}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com

# %%
people_df.sort_values(by = 'last_name')
# Out:
#   first_name last_name age                email
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com
# 0      Smith      Will  34  smithwill@gmail.com

# %%
people_df.sort_values(by = 'last_name', ascending = False)
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com

# %%
people_df.sort_values(by = ['last_name', 'first_name'])
# Out:
#   first_name last_name age                email
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 0      Smith      Will  34  smithwill@gmail.com

# %%
people_df.sort_values(by = ['last_name', 'first_name'], ascending =[False, True])
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com

# %%
people_df
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com

# %%
people_df.sort_values(by = ['last_name', 'first_name'], ascending =[False, True], inplace =True)

# %%
people_df
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com

# %%
people_df.sort_index()
# Out:
#   first_name last_name age                email
# 0      Smith      Will  34  smithwill@gmail.com
# 1      Rowan       Doe  45  rowanjohn@gmail.com
# 2      Alfie       Doe  23  alfiehaze@gmail.com
# 3       John       Doe  45    johndoe@gmail.com

# %%
df = pd.read_csv('survey_results_public.csv', low_memory=False)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %% [markdown]
# df.sort_values(by = 'Country')

# %%
df.sort_values(by = 'Country')
# Out:
#        ResponseId                                         MainBranch  \
# 6835         6836                     I am a developer by profession
# 6009         6010                     I am a developer by profession
# 15707       15708                     I am a developer by profession
# 7076         7077  I am not primarily a developer, but I write co...
# 19815       19816                              I am learning to code
# ...           ...                                                ...
# 49185       49186                     I am a developer by profession
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                      Age                                            EdLevel  \
# ...

# %%
df['Country']
# Out:
# 0            Ukraine
# 1        Netherlands
# 2            Ukraine
# 3            Ukraine
# 4            Ukraine
#             ...
# 49186            NaN
# 49187            NaN
# 49188          Italy
# 49189            NaN
# 49190            NaN
# Name: Country, Length: 49191, dtype: object

# %%
df.sort_values(by = 'Country', inplace = True)

# %%
df.head(10)
# Out:
#        ResponseId                                         MainBranch  \
# 6835         6836                     I am a developer by profession
# 6009         6010                     I am a developer by profession
# 15707       15708                     I am a developer by profession
# 7076         7077  I am not primarily a developer, but I write co...
# 19815       19816                              I am learning to code
# 44796       44797  I am not primarily a developer, but I write co...
# 45924       45925                     I am a developer by profession
# 27098       27099                     I am a developer by profession
# 40306       40307                     I am a developer by profession
# 40966       40967                     I am a developer by profession
#
#                      Age                                            EdLevel  \
# 6835     18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df['Country'].head(50)
# Out:
# 6835     Afghanistan
# 6009     Afghanistan
# 15707    Afghanistan
# 7076     Afghanistan
# 19815    Afghanistan
# 44796    Afghanistan
# 45924    Afghanistan
# 27098    Afghanistan
# 40306    Afghanistan
# 40966    Afghanistan
# 38608    Afghanistan
# 7924     Afghanistan
# 7166     Afghanistan
# 37730        Albania
# 14757        Albania
# 36996        Albania
# 48949        Albania
# 28587        Albania
# 2022         Albania
# 35183        Albania
# 16238        Albania
# 33939        Albania
# 45420        Albania
# 3887         Albania
# 44878        Albania
# 44945        Albania
# 35933        Albania
# 22399        Albania
# 8775         Albania
# 11873        Albania
# 41906        Albania
# 27801        Albania
# 16849        Albania
# 25303        Albania
# 3184         Albania
# 44462        Algeria
# 35358        Algeria
# 33029        Algeria
# 1840         Algeria
# 47922        Algeria
# 14679        Algeria
# 7105         Algeria
# 41295        Algeria
# ...

# %%
df[['Country','ConvertedCompYearly']].head(50)
# Out:
#            Country  ConvertedCompYearly
# 6835   Afghanistan                  NaN
# 6009   Afghanistan                986.0
# 15707  Afghanistan                  NaN
# 7076   Afghanistan               8450.0
# 19815  Afghanistan                  NaN
# 44796  Afghanistan                  NaN
# 45924  Afghanistan               7042.0
# 27098  Afghanistan                  NaN
# 40306  Afghanistan               9858.0
# 40966  Afghanistan              65000.0
# 38608  Afghanistan               1000.0
# 7924   Afghanistan                282.0
# 7166   Afghanistan               5200.0
# 37730      Albania              67779.0
# 14757      Albania              34804.0
# 36996      Albania                  NaN
# 48949      Albania              17402.0
# 28587      Albania             118286.0
# 2022       Albania             139218.0
# 35183      Albania                  NaN
# 16238      Albania                  NaN
# 33939      Albania              17734.0
# ...

# %%
df.sort_values(by =['Country','ConvertedCompYearly'], ascending =[True, False], inplace= True)

# %%
df[['Country','ConvertedCompYearly']].head(50)
# Out:
#            Country  ConvertedCompYearly
# 40966  Afghanistan              65000.0
# 40306  Afghanistan               9858.0
# 7076   Afghanistan               8450.0
# 45924  Afghanistan               7042.0
# 7166   Afghanistan               5200.0
# 38608  Afghanistan               1000.0
# 6009   Afghanistan                986.0
# 7924   Afghanistan                282.0
# 6835   Afghanistan                  NaN
# 15707  Afghanistan                  NaN
# 19815  Afghanistan                  NaN
# 44796  Afghanistan                  NaN
# 27098  Afghanistan                  NaN
# 2022       Albania             139218.0
# 28587      Albania             118286.0
# 3184       Albania             116014.0
# 37730      Albania              67779.0
# 35933      Albania              50000.0
# 14757      Albania              34804.0
# 33939      Albania              17734.0
# 48949      Albania              17402.0
# 3887       Albania              14187.0
# ...

# %%
df['ConvertedCompYearly'].nlargest(50)
# Out:
# 34267    50000000.0
# 28700    33552715.0
# 43143    18387548.0
# 35353    15430267.0
# 45971    13921760.0
# 48428    10000000.0
# 24900     9531653.0
# 10025     9000000.0
# 37352     6890299.0
# 30728     6371285.0
# 40418     6000000.0
# 19536     5810837.0
# 28055     5000000.0
# 14873     4706124.0
# 48023     3900562.0
# 28058     3900000.0
# 39349     3821169.0
# 25268     2500000.0
# 5410      2346000.0
# 34975     2000000.0
# 5327      1950000.0
# 40518     1820367.0
# 38007     1740220.0
# 15411     1700000.0
# 31876     1555205.0
# 9310      1500000.0
# 3265      1500000.0
# 11938     1497556.0
# 42326     1361415.0
# 2668      1300000.0
# 12055     1300000.0
# 22510     1279775.0
# 2725      1250000.0
# 38750     1239929.0
# 48839     1225273.0
# 27935     1200000.0
# 2812      1200000.0
# 19059     1160147.0
# 4583      1160147.0
# 32037     1160147.0
# 4842      1100000.0
# 31678     1100000.0
# 2087      1044132.0
# 14357     1036327.0
# 45555     1021061.0
# ...

# %%
df.nlargest(10,'ConvertedCompYearly')
# Out:
#        ResponseId                                         MainBranch  \
# 34267       34268                        I code primarily as a hobby
# 28700       28701                     I am a developer by profession
# 43143       43144                        I code primarily as a hobby
# 35353       35354                     I am a developer by profession
# 45971       45972  I work with developers or my work supports dev...
# 48428       48429                        I code primarily as a hobby
# 24900       24901                     I am a developer by profession
# 10025       10026                     I am a developer by profession
# 37352       37353                     I am a developer by profession
# 30728       30729                     I am a developer by profession
#
#                    Age                                          EdLevel  \
# 34267  55-64 years old              Associate degree (A.A., A.S., etc.)
# ...

# %%
df.nsmallest(10,'ConvertedCompYearly')
# Out:
#        ResponseId                                         MainBranch  \
# 34865       34866                     I am a developer by profession
# 41682       41683  I am not primarily a developer, but I write co...
# 34567       34568                     I am a developer by profession
# 27892       27893                              I am learning to code
# 28177       28178                     I am a developer by profession
# 42078       42079  I work with developers or my work supports dev...
# 16489       16490                              I am learning to code
# 4580         4581                     I am a developer by profession
# 21034       21035                     I am a developer by profession
# 26961       26962                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# 34865  35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...
